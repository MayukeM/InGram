# %% [markdown]
# # 验证集读取三元组函数
# class TestNewData():
# def read_triplet(self):
# path = '/root/autodl-tmp/InGram-main/data/NL-100'

# %%
path = '/root/autodl-tmp/InGram-main/data/NL-100/'
total_triplets = []
with open(path + '/msg.txt', 'r') as f:
    # 输出一共有多少行
    print(len(f.readlines()))
# Out:
# 2378

# %%
import sys
sys.path.append('/root/autodl-tmp/InGram-main/')
from dataset import TrainData, TestNewData
valid = TestNewData(path, data_type="valid")
# Out:
# -----Valid Data Statistics-----
# Message set has 2378 triplets
# Supervision set has 793 triplets
# 1709 entities, 53 relations, 3964 triplets

# %%
valid.id2ent, len(valid.id2ent)
# Out:
# (['concept_actor_biography',
#   'concept_buildingfeature_window',
#   'concept_actor_description',
#   'concept_actor_financial',
#   'concept_musicartist_times',
#   'concept_actor_pdf',
#   'concept_actor_puzzle',
#   'concept_agent_environment',
#   'concept_buildingfeature_windows',
#   'concept_agriculturalproduct_cotton',
#   'concept_insect_insects',
#   'concept_agriculturalproduct_herbs',
#   'concept_vegetable_vinegar',
#   'concept_country_region',
#   'concept_landscapefeatures_forest',
#   'concept_landscapefeatures_islands',
#   'concept_landscapefeatures_mountains',
#   'concept_agriculturalproduct_livestock',
#   'concept_meat_beef',
#   'concept_agriculturalproduct_milk_products',
#   'concept_beverage_milk',
#   'concept_agriculturalproduct_option',
#   'concept_agriculturalproduct_plants',
#   'concept_country_uk',
#   'concept_landscapefeatures_area',
#   'concept_landscapefeatures_estuaries',
#   'concept_landscapefeatures_lakes',
# ...

# %%
valid.id2rel, len(valid.id2rel)
# Out:
# (['concept:agentinvolvedwithitem',
#   'concept:agentcompeteswithagent',
#   'concept:agriculturalproducttoattractinsect',
#   'concept:agriculturalproductcookedwithagriculturalproduct',
#   'concept:agriculturalproductgrowninlandscapefeatures',
#   'concept:agriculturalproductincludingagriculturalproduct',
#   'concept:agriculturalproductcamefromcountry',
#   'concept:buildinglocatedincity',
#   'concept:animalistypeofanimal',
#   'concept:specializationof',
#   'concept:animaleatfood',
#   'concept:animaleatvegetable',
#   'concept:agentparticipatedinevent',
#   'concept:animalsuchasinsect',
#   'concept:athleteplayssport',
#   'concept:athleteplaysforteam',
#   'concept:athleteplaysinleague',
#   'concept:coachwontrophy',
#   'concept:agentbelongstoorganization',
#   'concept:athleteplayssportsteamposition',
#   'concept:attractionofcity',
#   'concept:automobilemakercardealersinstateorprovince',
#   'concept:automobilemakerdealersincountry',
# ...

# %%
valid.msg_triplets, len(valid.msg_triplets)
# Out:
# (array([[  0,   0,   1],
#         [  2,   0,   1],
#         [  3,   1,   4],
#         ...,
#         [215,  69, 347],
#         [ 98,  66, 821],
#         [930,  61,  96]]),
#  4756)

# %%
valid.sup_triplets, len(valid.sup_triplets)
# Out:
# (array([[  83,    8,  924],
#         [ 567,   27, 1615],
#         [  84,   11,  887],
#         ...,
#         [1057,    1,  198],
#         [ 816,   34,  814],
#         [  60,   34,  825]]),
#  793)

# %%
valid.filter_dict, len(valid.filter_dict)
# Out:
# ({('_', 0, 1): [0,
#    2,
#    5,
#    6,
#    21,
#    65,
#    69,
#    110,
#    111,
#    113,
#    116,
#    117,
#    232,
#    364,
#    423,
#    433,
#    439,
#    442,
#    444,
#    445,
#    446,
#    448,
#    503,
#    506,
#    512,
#    513,
#    514,
#    357,
#    518,
#    546,
#    548,
#    552,
#    553,
#    554,
#    559,
#    563,
#    571,
#    572,
#    574,
#    575,
#    576,
#    577,
#    581,
#    583,
#    589,
#    591,
#    592,
#    593,
#    597,
#    600,
#    601,
#    606,
#    610,
#    611,
#    612,
#    629,
#    664,
#    669,
#    671,
#    678,
#    680,
#    683,
#    685,
#    690,
#    715,
#    716,
#    721,
#    722,
#    726,
#    730,
#    740,
#    744,
#    745,
#    746,
#    747,
#    748,
#    749,
#    750,
#    751,
#    752,
#    753,
#    755,
#    757,
#    758,
#    760,
#    761,
#    772,
#    776,
#    777,
#    778,
#    783,
#    791,
#    792,
#    793,
#    794,
#    800,
#    828,
#    831,
#    870,
# ...
